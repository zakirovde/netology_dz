# %% [markdown]
# ## Получаем данные

# %%
import pandas as pd

# %%
import numpy as np
from tqdm import tqdm_notebook

# %%
df_ratings = pd.read_csv('../lecture-1/ratings.csv')
df_movies = pd.read_csv('../lecture-1/movies.csv')

# %%
df = pd.merge(df_ratings, df_movies, on='movieId')

# %%
del df['timestamp']
del df['genres']

# %%
df.head()
# Out:
#    userId  movieId  rating             title
# 0       1        1     4.0  Toy Story (1995)
# 1       5        1     4.0  Toy Story (1995)
# 2       7        1     4.5  Toy Story (1995)
# 3      15        1     2.5  Toy Story (1995)
# 4      17        1     4.5  Toy Story (1995)

# %% [markdown]
# ## Формируем векторное описание для фильма

# %%
df['userId'].describe()
# Out:
# count    100836.000000
# mean        326.127564
# std         182.618491
# min           1.000000
# 25%         177.000000
# 50%         325.000000
# 75%         477.000000
# max         610.000000
# Name: userId, dtype: float64

# %%
MAX_USER_ID = 610
MIN_USER_ID = 1

# %%
movie_names = df['title'].unique()

# %%
movie_names = movie_names.tolist()

# %%
movie_to_vector = {}

# %%
for movie in tqdm_notebook(movie_names):
    movie_to_vector[movie] = np.zeros((MAX_USER_ID,))
    for r in df[df['title'] == movie].iterrows():
        movie_to_vector[movie][r[1]['userId'] - MIN_USER_ID] = r[1]['rating']
# Out:
# HBox(children=(IntProgress(value=0, max=9719), HTML(value='')))

# %% [markdown]
# ## Ищем похожие

# %%
def find_similar(movie, dist_func, top=10):
    distances = {}
    target_movie = movie_to_vector[movie]
    for m in movie_names:
        distances[m] = dist_func(target_movie, movie_to_vector[m])
        
    distances_with_idx = [(i, distances[m]) for i, m in enumerate(movie_names)]
    distances_with_idx = sorted(distances_with_idx, key=lambda t: t[1], reverse=False)
    distances_with_idx = distances_with_idx[:top]
    
    return [(movie_names[i], d) for i, d in distances_with_idx]

# %%
from scipy.spatial.distance import cosine, euclidean, cityblock

# %%
find_similar('Toy Story (1995)', cityblock)
# Out:
# [('Toy Story (1995)', 0.0),
#  ('Toy Story 2 (1999)', 608.5),
#  ("Bug's Life, A (1998)", 698.5),
#  ('Groundhog Day (1993)', 714.0),
#  ('Nutty Professor, The (1996)', 714.0),
#  ('Willy Wonka & the Chocolate Factory (1971)', 718.0),
#  ('Mission: Impossible (1996)', 722.0),
#  ('Babe (1995)', 722.5),
#  ('Monsters, Inc. (2001)', 725.0),
#  ('Toy Story 3 (2010)', 728.0)]

# %% [markdown]
# ## User 2 Item

# %%
# !pip install surprise
# Out:
# Requirement already satisfied: surprise in /Users/fantomius/anaconda3/lib/python3.7/site-packages (0.1)
# Requirement already satisfied: scikit-surprise in /Users/fantomius/anaconda3/lib/python3.7/site-packages (from surprise) (1.0.6)
# Requirement already satisfied: joblib>=0.11 in /Users/fantomius/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (0.13.2)
# Requirement already satisfied: scipy>=1.0.0 in /Users/fantomius/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /Users/fantomius/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.12.0)
# Requirement already satisfied: numpy>=1.11.2 in /Users/fantomius/anaconda3/lib/python3.7/site-packages (from scikit-surprise->surprise) (1.16.4)

# %%
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
df_ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_for_surpise = df_ratings[['userId', 'movieId', 'rating']]

# %%
df_for_surpise.columns = ['uid', 'iid', 'rating']

# %%
df_for_surpise.head()
# Out:
#    uid  iid  rating
# 0    1    1     4.0
# 1    1    3     4.0
# 2    1    6     4.0
# 3    1   47     5.0
# 4    1   50     5.0

# %%
reader = Reader(rating_scale=(0.5, 5))

# %%
dataset = Dataset.load_from_df(df_for_surpise, reader)

# %%
trainset, testset = train_test_split(dataset, test_size=0.2)

# %%
algo = KNNBasic(k=40, sim_options={'name': 'cosine', 'user_based': True}, user_based=True)

# %%
algo.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.7462
# 0.7462106589568676

# %%
testset
# Out:
# [(496, 904, 5.0),
#  (339, 1198, 5.0),
#  (292, 5299, 4.0),
#  (52, 73017, 5.0),
#  (474, 25795, 3.5),
#  (1, 2048, 5.0),
#  (83, 364, 3.5),
#  (274, 45517, 3.5),
#  (338, 30749, 3.5),
#  (376, 7254, 4.0),
#  (23, 1960, 3.0),
#  (429, 185, 5.0),
#  (84, 1307, 5.0),
#  (438, 30898, 3.0),
#  (42, 2144, 3.0),
#  (477, 593, 5.0),
#  (68, 1049, 3.5),
#  (477, 77455, 4.5),
#  (555, 1518, 1.0),
#  (6, 355, 4.0),
#  (587, 3418, 5.0),
#  (121, 237, 4.0),
#  (128, 945, 5.0),
#  (438, 2540, 2.5),
#  (474, 1230, 4.0),
#  (91, 1215, 5.0),
#  (176, 434, 4.0),
#  (353, 593, 5.0),
#  (182, 6645, 4.5),
#  (448, 134853, 4.0),
#  (76, 1278, 4.0),
#  (528, 91529, 4.5),
#  (468, 292, 4.0),
#  (212, 86190, 3.5),
#  (474, 2664, 4.0),
#  (318, 86880, 3.5),
#  (469, 2872, 5.0),
#  (20, 4022, 3.5),
#  (5, 592, 3.0),
#  (401, 5952, 3.0),
#  (47, 2121, 2.5),
#  (474, 2396, 4.0),
#  (517, 1967, 1.0),
#  (19, 2468, 2.0),
#  (356, 3477, 5.0),
#  (438, 2712, 3.0),
#  (332, 1590, 2.5),
#  (318, 3717, 3.0),
#  (249, 2605, 3.5),
#  (419, 175, 4.0),
#  (414, 96610, 4.5),
#  (260, 5219, 3.0),
#  (480, 4643, 2.5),
#  (282, 2716, 4.5),
#  (525, 2139, 3.5),
#  (260, 8784, 0.5),
#  (448, 34520, 2.0),
#  (448, 4233, 2.5),
#  (426, 3969, 2.5),
#  (380, 94777, 5.0),
#  (549, 2959, 5.0),
#  (608, 1036, 3.0),
#  (601, 95167, 4.0),
#  (597, 2710, 3.0),
#  (159, 1569, 3.0),
#  (438, 2628, 3.0),
#  (166, 1682, 5.0),
#  (586, 1580, 5.0),
#  (292, 164909, 2.5),
#  (18, 140289, 4.0),
#  (331, 4638, 2.0),
#  (407, 68954, 3.0),
#  (91, 7561, 3.5),
#  (544, 736, 5.0),
#  (205, 81834, 4.0),
#  (300, 7361, 5.0),
#  (140, 541, 3.0),
#  (414, 143355, 4.5),
#  (520, 4027, 5.0),
#  (266, 367, 3.0),
#  (608, 2672, 3.5),
#  (443, 2959, 4.0),
#  (307, 1089, 4.0),
#  (115, 487, 5.0),
#  (448, 4487, 1.0),
#  (68, 1453, 3.0),
#  (47, 1968, 2.5),
#  (414, 1779, 1.0),
#  (111, 7254, 0.5),
#  (284, 356, 5.0),
#  (599, 137345, 2.0),
#  (177, 3977, 3.0),
#  (600, 902, 2.0),
#  (111, 83349, 3.5),
#  (531, 5349, 5.0),
#  (387, 44, 1.0),
#  (591, 2722, 2.0),
#  (598, 593, 0.5),
#  (610, 78836, 5.0),
#  (318, 63876, 4.0),
#  (369, 1371, 3.0),
#  (129, 480, 3.5),
#  (450, 260, 5.0),
#  (469, 2613, 2.0),
#  (45, 2140, 4.0),
#  (414, 1024, 4.0),
#  (274, 5874, 2.0),
#  (182, 3949, 4.0),
#  (265, 388, 2.0),
#  (129, 485, 3.5),
#  (6, 277, 5.0),
#  (288, 1646, 3.0),
#  (249, 45431, 3.5),
#  (602, 474, 5.0),
#  (95, 7, 3.0),
#  (313, 4518, 4.0),
#  (111, 327, 2.5),
#  (275, 2937, 5.0),
#  (568, 1103, 5.0),
#  (444, 97, 5.0),
#  (599, 73, 3.0),
#  (113, 509, 5.0),
#  (425, 2407, 3.0),
#  (462, 64839, 4.0),
#  (253, 6016, 4.5),
#  (1, 2406, 4.0),
#  (416, 4995, 2.5),
#  (408, 51662, 4.0),
#  (343, 1200, 3.5),
#  (231, 1270, 4.0),
#  (586, 168418, 5.0),
#  (93, 1676, 4.0),
#  (305, 163, 5.0),
#  (273, 150, 3.0),
#  (282, 4262, 4.5),
#  (28, 161, 3.0),
#  (381, 5618, 5.0),
#  (402, 477, 3.0),
#  (599, 3342, 2.5),
#  (238, 4848, 4.0),
#  (608, 2468, 2.0),
#  (68, 64622, 3.5),
#  (514, 2455, 4.0),
#  (597, 1961, 5.0),
#  (599, 3994, 2.5),
#  (18, 163, 4.0),
#  (385, 1200, 4.0),
#  (274, 33085, 2.5),
#  (500, 595, 4.0),
#  (98, 81845, 5.0),
#  (249, 94777, 4.0),
#  (232, 69069, 3.5),
#  (305, 7454, 3.0),
#  (573, 6188, 4.5),
#  (412, 17, 5.0),
#  (298, 109487, 3.0),
#  (82, 7153, 4.0),
#  (18, 44022, 3.5),
#  (346, 2858, 4.5),
#  (448, 912, 4.5),
#  (600, 4069, 2.5),
#  (402, 589, 5.0),
#  (454, 101, 3.0),
#  (280, 41566, 3.5),
#  (307, 110, 3.5),
#  (246, 224, 3.5),
#  (448, 116419, 1.5),
#  (19, 153, 2.0),
#  (357, 1073, 3.5),
#  (195, 1089, 5.0),
#  (45, 1042, 3.0),
#  (447, 593, 4.0),
#  (307, 52281, 4.0),
#  (610, 4979, 4.0),
#  (600, 3250, 2.5),
#  (160, 356, 3.0),
#  (274, 1863, 3.0),
#  (387, 8042, 4.0),
#  (526, 608, 4.5),
#  (129, 2987, 4.0),
#  (420, 3081, 4.5),
#  (314, 165, 2.0),
#  (448, 1017, 3.0),
#  (244, 349, 4.0),
#  (305, 115149, 3.5),
#  (310, 2457, 4.5),
#  (599, 1784, 3.5),
#  (474, 2927, 4.0),
#  (103, 2054, 3.5),
#  (474, 8331, 4.0),
#  (380, 3986, 3.0),
#  (596, 1046, 4.0),
#  (429, 186, 4.0),
#  (444, 480, 3.0),
#  (263, 6539, 4.0),
#  (134, 48, 3.0),
#  (73, 109483, 2.0),
#  (514, 1292, 3.5),
#  (288, 1194, 1.0),
#  (346, 307, 3.5),
#  (472, 48516, 5.0),
#  (304, 296, 5.0),
#  (122, 104841, 4.5),
#  (599, 7354, 3.5),
#  (483, 105325, 1.0),
#  (318, 6502, 3.5),
#  (534, 69278, 3.5),
#  (600, 1020, 2.0),
#  (91, 4624, 3.0),
#  (474, 7810, 3.0),
#  (221, 8873, 4.5),
#  (555, 1258, 5.0),
#  (354, 6059, 3.5),
#  (57, 2002, 3.0),
#  (332, 27801, 3.5),
#  (95, 2115, 4.5),
#  (380, 2018, 3.0),
#  (122, 714, 5.0),
#  (199, 5299, 3.5),
#  (166, 593, 4.0),
#  (246, 84944, 5.0),
#  (380, 1676, 5.0),
#  (232, 7257, 3.0),
#  (186, 4321, 5.0),
#  (65, 97752, 4.0),
#  (274, 54995, 4.5),
#  (68, 4124, 2.0),
#  (288, 1199, 4.0),
#  (90, 68, 3.0),
#  (564, 93510, 4.0),
#  (480, 300, 4.5),
#  (139, 86880, 2.0),
#  (274, 46965, 3.0),
#  (599, 1320, 3.0),
#  (14, 590, 4.0),
#  (346, 3160, 4.5),
#  (84, 299, 5.0),
#  (219, 4649, 4.0),
#  (105, 1272, 3.5),
#  (573, 4306, 4.5),
#  (130, 588, 2.0),
#  (105, 750, 4.0),
#  (380, 65682, 4.0),
#  (608, 8957, 3.5),
#  (182, 4577, 4.5),
#  (305, 106002, 4.0),
#  (50, 109374, 3.0),
#  (247, 32587, 3.0),
#  (474, 5008, 4.0),
#  (111, 45447, 4.0),
#  (426, 59784, 2.5),
#  (525, 59126, 3.0),
#  (600, 3271, 2.0),
#  (605, 27251, 1.0),
#  (484, 1682, 4.0),
#  (448, 72405, 2.0),
#  (62, 74458, 4.0),
#  (1, 2115, 5.0),
#  (414, 3672, 2.0),
#  (298, 5991, 2.5),
#  (288, 3308, 3.0),
#  (414, 145, 2.0),
#  (80, 1676, 3.5),
#  (255, 2915, 2.0),
#  (380, 3511, 3.0),
#  (105, 99145, 4.5),
#  (119, 356, 4.0),
#  (105, 3081, 4.0),
#  (254, 4306, 5.0),
#  (307, 1101, 0.5),
#  (600, 2124, 4.0),
#  (425, 7143, 3.5),
#  (534, 7153, 4.5),
#  (600, 45081, 2.0),
#  (132, 1271, 3.5),
#  (100, 1380, 4.0),
#  (95, 3298, 3.0),
#  (249, 45672, 4.5),
#  (275, 3552, 5.0),
#  (441, 2628, 4.5),
#  (606, 5319, 4.0),
#  (239, 1917, 4.0),
#  (474, 6002, 3.5),
#  (414, 3996, 5.0),
#  (161, 3429, 5.0),
#  (591, 2683, 5.0),
#  (15, 2858, 4.0),
#  (148, 68954, 4.0),
#  (448, 102123, 4.0),
#  (202, 1312, 2.0),
#  (287, 4299, 0.5),
#  (199, 3035, 4.0),
#  (610, 68237, 4.0),
#  (474, 1274, 2.0),
#  (274, 1753, 3.5),
#  (216, 1923, 4.0),
#  (202, 592, 3.0),
#  (448, 94323, 2.0),
#  (111, 1513, 3.0),
#  (62, 5378, 4.5),
#  (451, 788, 1.0),
#  (587, 3450, 1.0),
#  (534, 1198, 4.0),
#  (79, 858, 5.0),
#  (606, 3259, 3.5),
#  (177, 1244, 4.0),
#  (564, 93326, 2.5),
#  (167, 1197, 4.5),
#  (474, 3271, 3.0),
#  (380, 58559, 5.0),
#  (481, 1438, 2.0),
#  (20, 4344, 3.5),
#  (526, 109374, 4.0),
#  (222, 1610, 3.5),
#  (474, 5073, 3.0),
#  (105, 89492, 3.5),
#  (107, 104, 3.0),
#  (182, 1480, 4.0),
#  (599, 780, 3.5),
#  (57, 781, 4.0),
#  (474, 48698, 4.0),
#  (559, 532, 3.0),
#  (217, 1080, 2.0),
#  (425, 4995, 4.0),
#  (103, 72226, 4.0),
#  (195, 1673, 4.0),
#  (479, 2583, 5.0),
#  (312, 2762, 4.0),
#  (414, 4773, 2.0),
#  (187, 8228, 4.0),
#  (288, 585, 3.0),
#  (103, 105844, 4.0),
#  (20, 262, 4.5),
#  (550, 167296, 0.5),
#  (294, 2468, 2.0),
#  (4, 4166, 3.0),
#  (41, 2724, 2.0),
#  (135, 1483, 4.0),
#  (166, 3949, 4.0),
#  (562, 58559, 4.0),
#  (318, 4754, 3.5),
#  (474, 906, 5.0),
#  (400, 52722, 2.5),
#  (474, 6791, 5.0),
#  (606, 56333, 3.5),
#  (380, 6157, 3.0),
#  (608, 4865, 4.0),
#  (50, 114335, 3.0),
#  (257, 594, 3.5),
#  (599, 2311, 2.5),
#  (469, 1270, 3.0),
#  (446, 585, 3.0),
#  (143, 31433, 4.0),
#  (610, 3108, 4.5),
#  (469, 1921, 4.0),
#  (372, 39, 3.0),
#  (571, 968, 5.0),
#  (354, 4239, 4.5),
#  (475, 8371, 4.5),
#  (564, 49286, 3.0),
#  (294, 516, 3.0),
#  (356, 5577, 4.5),
#  (236, 2505, 4.0),
#  (555, 3534, 5.0),
#  (470, 10, 3.0),
#  (534, 87192, 3.0),
#  (414, 2762, 3.0),
#  (272, 4993, 2.0),
#  (599, 1378, 1.5),
#  (520, 1748, 4.5),
#  (532, 1233, 5.0),
#  (70, 1959, 4.5),
#  (339, 89864, 4.0),
#  (446, 733, 3.0),
#  (267, 2396, 5.0),
#  (82, 7142, 3.5),
#  (135, 1792, 2.0),
#  (164, 589, 5.0),
#  (387, 1770, 3.0),
#  (177, 3753, 3.5),
#  (415, 2997, 4.0),
#  (599, 4043, 3.0),
#  (370, 2959, 4.5),
#  (222, 49396, 3.0),
#  (119, 1580, 4.0),
#  (414, 3108, 3.0),
#  (534, 1784, 3.5),
#  (122, 6377, 4.5),
#  (588, 316, 2.0),
#  (134, 367, 3.0),
#  (23, 6, 4.0),
#  (103, 2088, 4.0),
#  (118, 2378, 3.0),
#  (567, 34150, 1.0),
#  (414, 8784, 5.0),
#  (496, 84374, 3.0),
#  (44, 3, 3.0),
#  (268, 2571, 5.0),
#  (232, 145, 3.5),
#  (234, 2384, 2.0),
#  (368, 3370, 3.0),
#  (317, 84392, 3.0),
#  (63, 2571, 3.5),
#  (104, 1391, 3.0),
#  (212, 1968, 3.0),
#  (15, 134853, 4.5),
#  (219, 10, 4.5),
#  (561, 2797, 4.0),
#  (445, 2762, 4.0),
#  (182, 4919, 3.5),
#  (82, 1221, 3.0),
#  (237, 63082, 3.5),
#  (182, 3698, 4.0),
#  (610, 56782, 5.0),
#  (354, 2997, 3.5),
#  (63, 2788, 5.0),
#  (274, 5556, 1.0),
#  (414, 55080, 4.0),
#  (282, 1240, 4.5),
#  (187, 2692, 3.0),
#  (464, 1206, 3.0),
#  (177, 2420, 3.0),
#  (529, 736, 4.0),
#  (425, 3114, 3.0),
#  (234, 3176, 4.0),
#  (3, 914, 0.5),
#  (103, 1994, 4.0),
#  (509, 108932, 4.0),
#  (380, 115617, 5.0),
#  (129, 3793, 4.0),
#  (307, 5524, 2.5),
#  (143, 69757, 5.0),
#  (489, 87485, 3.5),
#  (224, 260, 2.0),
#  (573, 836, 3.0),
#  (590, 7059, 3.5),
#  (89, 5419, 5.0),
#  (606, 1259, 4.0),
#  (479, 2701, 1.0),
#  (331, 6863, 3.5),
#  (199, 4641, 4.0),
#  (233, 778, 3.5),
#  (414, 1339, 4.0),
#  (74, 6244, 4.0),
#  (4, 553, 2.0),
#  (249, 84374, 3.5),
#  (599, 168250, 3.0),
#  (274, 52458, 2.5),
#  (153, 81845, 2.5),
#  (419, 86668, 5.0),
#  (187, 3091, 4.5),
#  (335, 802, 3.0),
#  (469, 2393, 4.0),
#  (365, 2144, 4.0),
#  (76, 48, 0.5),
#  (166, 1276, 4.5),
#  (318, 88125, 4.0),
#  (57, 2115, 3.0),
#  (40, 351, 4.0),
#  (387, 8950, 4.0),
#  (382, 1204, 5.0),
#  (95, 5956, 4.0),
#  (603, 1042, 3.0),
#  (212, 122926, 4.0),
#  (425, 2916, 3.5),
#  (117, 204, 3.0),
#  (434, 34, 3.5),
#  (89, 30793, 2.0),
#  (380, 95147, 3.0),
#  (111, 96588, 4.5),
#  (83, 48774, 5.0),
#  (137, 3507, 4.0),
#  (514, 296, 4.0),
#  (68, 4896, 5.0),
#  (1, 356, 4.0),
#  (590, 5388, 3.5),
#  (418, 2959, 5.0),
#  (294, 597, 1.0),
#  (572, 1834, 4.0),
#  (599, 2829, 2.5),
#  (460, 49272, 4.0),
#  (308, 1198, 1.0),
#  (201, 1198, 5.0),
#  (462, 2985, 4.5),
#  (414, 2011, 3.0),
#  (414, 5788, 2.5),
#  (177, 63062, 4.0),
#  (414, 55052, 3.5),
#  (308, 106642, 5.0),
#  (269, 494, 3.0),
#  (497, 1193, 5.0),
#  (486, 593, 3.0),
#  (599, 57499, 3.0),
#  (462, 3467, 3.5),
#  (448, 4254, 1.0),
#  (393, 91658, 0.5),
#  (182, 1833, 3.5),
#  (600, 1517, 3.0),
#  (432, 81591, 5.0),
#  (608, 1513, 0.5),
#  (477, 1367, 3.0),
#  (514, 3041, 2.0),
#  (92, 107, 5.0),
#  (560, 3578, 4.0),
#  (177, 46578, 4.5),
#  (221, 1283, 4.5),
#  (415, 2764, 4.5),
#  (356, 1198, 4.0),
#  (68, 420, 1.0),
#  (380, 8860, 4.0),
#  (318, 120761, 3.5),
#  (278, 2352, 4.5),
#  (226, 4782, 2.0),
#  (301, 2490, 1.0),
#  (254, 4034, 4.0),
#  (377, 8641, 4.5),
#  (43, 253, 4.0),
#  (599, 104841, 3.0),
#  (424, 1252, 3.5),
#  (453, 231, 5.0),
#  (380, 6242, 3.0),
#  (15, 589, 5.0),
#  (11, 457, 5.0),
#  (410, 3671, 4.0),
#  (331, 64957, 3.0),
#  (116, 1247, 2.0),
#  (382, 117545, 3.5),
#  (184, 157369, 4.0),
#  (438, 588, 4.0),
#  (590, 2640, 4.0),
#  (332, 2657, 4.0),
#  (45, 1407, 4.5),
#  (21, 109374, 3.5),
#  (75, 47, 2.0),
#  (198, 1627, 1.0),
#  (177, 4085, 3.5),
#  (288, 2313, 3.0),
#  (19, 3752, 3.0),
#  (517, 68793, 3.0),
#  (469, 1388, 3.0),
#  (586, 120799, 4.0),
#  (486, 266, 5.0),
#  (299, 1387, 4.0),
#  (298, 111113, 2.0),
#  (305, 72294, 3.5),
#  (474, 2072, 1.0),
#  (29, 48774, 4.5),
#  (510, 2000, 3.0),
#  (389, 788, 4.0),
#  (391, 242, 4.0),
#  (222, 1408, 3.5),
#  (416, 356, 2.5),
#  (552, 4019, 4.0),
#  (186, 2054, 4.0),
#  (201, 2094, 4.0),
#  (330, 16, 3.5),
#  (331, 33615, 2.5),
#  (387, 2550, 4.0),
#  (555, 790, 2.0),
#  (567, 97836, 1.5),
#  (340, 253, 4.0),
#  (520, 6979, 4.0),
#  (334, 50601, 3.5),
#  (495, 1721, 5.0),
#  (448, 68793, 3.0),
#  (541, 132, 4.0),
#  (418, 79132, 4.0),
#  (169, 3988, 5.0),
#  (200, 2502, 4.0),
#  (573, 94864, 4.5),
#  (51, 2634, 3.0),
#  (404, 315, 3.0),
#  (199, 1518, 4.0),
#  (599, 8638, 3.0),
#  (403, 2420, 3.5),
#  (275, 4037, 5.0),
#  (66, 1216, 4.5),
#  (18, 480, 3.5),
#  (256, 6586, 4.0),
#  (117, 661, 3.0),
#  (68, 2078, 3.0),
#  (20, 1722, 3.0),
#  (610, 65514, 4.0),
#  (232, 6333, 3.5),
#  (464, 653, 2.5),
#  (386, 367, 1.0),
#  (322, 1610, 3.0),
#  (387, 47465, 1.5),
#  (415, 1580, 3.5),
#  (521, 733, 4.0),
#  (52, 2959, 4.5),
#  (28, 5445, 3.5),
#  (387, 2991, 3.5),
#  (483, 94810, 5.0),
#  (510, 7028, 2.5),
#  (171, 32, 5.0),
#  (17, 858, 5.0),
#  (177, 89745, 4.0),
#  (226, 4344, 3.0),
#  (297, 292, 2.0),
#  (562, 35836, 3.0),
#  (414, 4777, 2.5),
#  (50, 7438, 3.5),
#  (599, 95780, 4.0),
#  (274, 1476, 3.5),
#  (606, 3252, 4.0),
#  (469, 29, 4.0),
#  (219, 4327, 3.0),
#  (264, 364, 3.5),
#  (219, 7367, 3.0),
#  (294, 1215, 4.0),
#  (97, 858, 5.0),
#  (130, 153, 4.0),
#  (222, 1092, 1.5),
#  (382, 160980, 4.0),
#  (474, 8784, 4.0),
#  (187, 586, 1.5),
#  (29, 4980, 2.0),
#  (101, 2490, 2.0),
#  (156, 2371, 1.0),
#  (210, 34405, 4.5),
#  (6, 236, 4.0),
#  (51, 2023, 3.5),
#  (436, 262, 4.0),
#  (111, 63479, 4.5),
#  (414, 249, 4.0),
#  (414, 45210, 4.0),
#  (137, 7171, 4.0),
#  (307, 5349, 4.0),
#  (606, 605, 3.0),
#  (526, 30707, 3.0),
#  (68, 1885, 2.5),
#  (597, 1265, 5.0),
#  (143, 71535, 1.0),
#  (14, 597, 3.0),
#  (425, 1215, 3.5),
#  (414, 2100, 3.0),
#  (186, 4121, 4.0),
#  (486, 592, 4.0),
#  (139, 4993, 4.0),
#  (222, 78469, 2.5),
#  (345, 1203, 5.0),
#  (97, 4306, 5.0),
#  (487, 7438, 4.0),
#  (425, 6593, 3.0),
#  (110, 110, 3.5),
#  (448, 60487, 3.0),
#  (432, 47, 4.0),
#  (339, 6711, 4.0),
#  (466, 91500, 2.5),
#  (580, 62, 2.0),
#  (177, 4022, 3.0),
#  (599, 6324, 2.5),
#  (414, 2883, 4.0),
#  (381, 379, 3.5),
#  (93, 1641, 4.0),
#  (606, 17, 4.0),
#  (117, 551, 4.0),
#  (202, 1265, 5.0),
#  (346, 902, 3.0),
#  (169, 3147, 4.5),
#  (368, 316, 2.0),
#  (274, 61132, 3.5),
#  (129, 3977, 3.5),
#  (111, 3275, 5.0),
#  (57, 1197, 5.0),
#  (554, 923, 2.0),
#  (599, 93208, 2.0),
#  (604, 261, 4.0),
#  (474, 8275, 3.5),
#  (480, 3978, 2.5),
#  (182, 3328, 5.0),
#  (274, 3826, 2.0),
#  (325, 1517, 4.0),
#  (600, 5992, 1.0),
#  (601, 115617, 4.5),
#  (196, 1036, 4.5),
#  (480, 3852, 4.0),
#  (555, 2054, 3.0),
#  (226, 30810, 4.5),
#  (198, 3448, 5.0),
#  (472, 1693, 4.0),
#  (356, 52435, 1.5),
#  (139, 3300, 2.0),
#  (42, 1466, 4.0),
#  (469, 1676, 1.0),
#  (217, 474, 4.0),
#  (425, 1784, 3.5),
#  (414, 4487, 3.0),
#  (600, 2410, 3.0),
#  (564, 134368, 3.5),
#  (111, 74458, 3.5),
#  (89, 56367, 2.0),
#  (68, 5329, 3.0),
#  (610, 3908, 2.5),
#  (15, 256, 3.0),
#  (103, 551, 4.0),
#  (602, 482, 3.0),
#  (610, 79132, 4.0),
#  (447, 296, 5.0),
#  (57, 2291, 4.0),
#  (377, 71302, 4.5),
#  (453, 3948, 4.0),
#  (318, 46578, 4.5),
#  (367, 2529, 3.0),
#  (599, 26812, 2.5),
#  (62, 136864, 4.0),
#  (21, 2762, 0.5),
#  (580, 3032, 3.5),
#  (541, 316, 5.0),
#  (249, 7454, 3.0),
#  (204, 79008, 3.5),
#  (21, 109723, 3.5),
#  (191, 140, 3.0),
#  (190, 5956, 3.0),
#  (226, 3793, 3.5),
#  (87, 60, 3.0),
#  (475, 92259, 5.0),
#  (495, 69481, 4.5),
#  (210, 122916, 4.5),
#  (98, 56152, 4.0),
#  (555, 2021, 3.0),
#  (105, 8957, 4.0),
#  (600, 2724, 1.5),
#  (380, 1760, 2.5),
#  (326, 2020, 4.0),
#  (414, 47950, 3.0),
#  (596, 122918, 4.0),
#  (491, 106782, 4.5),
#  (249, 8861, 3.0),
#  (200, 39, 5.0),
#  (243, 442, 4.0),
#  (477, 7335, 4.0),
#  (474, 111, 4.0),
#  (525, 2142, 3.5),
#  (301, 8961, 4.0),
#  (313, 2034, 4.0),
#  (580, 6537, 4.0),
#  (489, 370, 0.5),
#  (425, 150, 3.0),
#  (260, 6502, 4.5),
#  (89, 788, 2.5),
#  (334, 7451, 3.5),
#  (135, 1717, 3.0),
#  (249, 1499, 2.0),
#  (381, 78499, 4.0),
#  (119, 56174, 4.5),
#  (599, 6874, 5.0),
#  (143, 96821, 2.0),
#  (368, 2153, 2.0),
#  (525, 8533, 3.5),
#  (135, 3708, 4.0),
#  (200, 6383, 4.0),
#  (469, 2160, 4.0),
#  (68, 500, 3.0),
#  (600, 2888, 1.5),
#  (117, 783, 4.0),
#  (380, 733, 3.0),
#  (247, 5378, 2.0),
#  (18, 53464, 2.5),
#  (606, 27744, 4.5),
#  (607, 2054, 3.0),
#  (599, 237, 2.0),
#  (580, 1266, 4.0),
#  (425, 8807, 4.0),
#  (457, 733, 5.0),
#  (387, 2968, 3.5),
#  (425, 50, 4.5),
#  (104, 1088, 3.0),
#  (307, 596, 2.5),
#  (606, 6376, 4.5),
#  (199, 1091, 1.5),
#  (276, 837, 4.0),
#  (177, 2724, 3.5),
#  (489, 2288, 3.0),
#  (306, 133419, 4.0),
#  (590, 2944, 4.0),
#  (326, 6867, 4.0),
#  (560, 94959, 3.5),
#  (249, 51255, 3.5),
#  (599, 6804, 2.0),
#  (28, 54736, 2.5),
#  (349, 587, 3.0),
#  (585, 7254, 2.5),
#  (330, 1320, 3.5),
#  (305, 104841, 3.0),
#  (19, 422, 3.0),
#  (469, 2476, 5.0),
#  (298, 3984, 3.0),
#  (391, 4995, 4.0),
#  (1, 2161, 5.0),
#  (51, 1674, 5.0),
#  (301, 4226, 4.0),
#  (22, 2058, 0.5),
#  (608, 3160, 4.0),
#  (91, 1356, 3.5),
#  (330, 5378, 4.0),
#  (597, 2802, 3.0),
#  (538, 69844, 4.0),
#  (27, 2355, 3.0),
#  (97, 4963, 5.0),
#  (249, 83349, 3.0),
#  (111, 135536, 4.0),
#  (68, 5103, 2.5),
#  (249, 88785, 3.5),
#  (474, 8614, 3.0),
#  (177, 63859, 2.5),
#  (606, 4392, 3.0),
#  (102, 480, 3.0),
#  (474, 5293, 3.5),
#  (91, 377, 3.0),
#  (27, 5060, 2.0),
#  (249, 104879, 5.0),
#  (282, 2378, 4.0),
#  (387, 2402, 2.0),
#  (420, 3354, 3.0),
#  (410, 1084, 4.0),
#  (182, 3826, 2.5),
#  (448, 3107, 4.0),
#  (310, 2671, 4.0),
#  (221, 1914, 4.0),
#  (288, 2035, 3.0),
#  (414, 3378, 4.0),
#  (104, 5952, 4.0),
#  (182, 597, 3.5),
#  (233, 1193, 3.0),
#  (159, 166643, 5.0),
#  (543, 1347, 5.0),
#  (351, 84152, 3.5),
#  (603, 1295, 2.0),
#  (318, 33903, 3.5),
#  (607, 2403, 5.0),
#  (66, 1080, 4.0),
#  (392, 3004, 1.0),
#  (145, 592, 3.0),
#  (596, 59667, 4.0),
#  (524, 151, 5.0),
#  (414, 2026, 2.0),
#  (111, 58156, 3.5),
#  (62, 166635, 3.5),
#  (590, 673, 3.0),
#  (437, 529, 5.0),
#  (305, 103253, 4.0),
#  (6, 489, 3.0),
#  (526, 1202, 4.0),
#  (422, 5039, 4.0),
#  (483, 53123, 5.0),
#  (603, 3168, 5.0),
#  (365, 8874, 4.0),
#  (274, 2080, 3.0),
#  (600, 1213, 2.0),
#  (474, 6852, 3.5),
#  (274, 33679, 2.5),
#  (418, 3147, 4.5),
#  (601, 2959, 5.0),
#  (231, 589, 5.0),
#  (152, 64620, 4.0),
#  (517, 26614, 2.5),
#  (313, 1882, 1.0),
#  (448, 8493, 3.0),
#  (462, 4973, 1.5),
#  (331, 6541, 2.0),
#  (277, 656, 3.0),
#  (469, 728, 3.0),
#  (610, 3999, 3.0),
#  (105, 4963, 4.0),
#  (474, 1748, 4.0),
#  (600, 552, 3.5),
#  (21, 4993, 1.5),
#  (483, 94266, 3.5),
#  (608, 1089, 4.0),
#  (274, 5989, 4.0),
#  (414, 5345, 3.0),
#  (230, 34330, 3.0),
#  (274, 5218, 3.5),
#  (211, 2858, 4.0),
#  (128, 1080, 4.0),
#  (52, 65514, 3.5),
#  (18, 1198, 4.0),
#  (592, 442, 4.0),
#  (199, 5481, 3.0),
#  (450, 1193, 5.0),
#  (325, 4717, 4.0),
#  (298, 6702, 0.5),
#  (331, 54286, 4.0),
#  (382, 2671, 3.5),
#  (95, 1240, 5.0),
#  (328, 1302, 0.5),
#  (555, 2770, 2.0),
#  (249, 71264, 4.0),
#  (453, 648, 3.0),
#  (292, 3682, 4.5),
#  (111, 3273, 0.5),
#  (166, 7153, 5.0),
#  (416, 6539, 2.0),
#  (160, 1562, 1.0),
#  (484, 3948, 4.0),
#  (181, 10, 2.0),
#  (95, 6333, 4.0),
#  (453, 1616, 3.0),
#  (411, 223, 4.0),
#  (232, 53125, 3.5),
#  (219, 3593, 0.5),
#  (343, 8253, 1.5),
#  (317, 94959, 3.0),
#  (387, 3840, 2.0),
#  (599, 3213, 2.5),
#  (477, 5669, 4.0),
#  (380, 1200, 5.0),
#  (85, 1449, 4.0),
#  (268, 2829, 3.0),
#  (281, 428, 3.5),
#  (480, 1441, 3.0),
#  (385, 728, 5.0),
#  (328, 50, 4.0),
#  (610, 114707, 3.0),
#  (447, 292, 3.0),
#  (610, 59022, 4.0),
#  (474, 4558, 2.0),
#  (606, 1844, 4.0),
#  (380, 899, 3.0),
#  (66, 4322, 4.0),
#  (561, 4121, 3.0),
#  (579, 838, 5.0),
#  (332, 85510, 3.5),
#  (428, 8810, 4.0),
#  (553, 5989, 5.0),
#  (68, 256, 1.5),
#  (372, 1275, 3.0),
#  (438, 4343, 3.0),
#  (318, 6953, 4.0),
#  (608, 203, 2.5),
#  (376, 54286, 5.0),
#  (599, 2953, 2.5),
#  (381, 2788, 4.0),
#  (579, 1831, 3.0),
#  (608, 95, 2.0),
#  (220, 2571, 5.0),
#  (448, 2264, 3.0),
#  (100, 2108, 3.5),
#  (89, 34332, 4.5),
#  (599, 96655, 2.5),
#  (462, 82857, 4.5),
#  (448, 2002, 3.0),
#  (332, 7063, 4.0),
#  (387, 7265, 3.0),
#  (99, 256, 4.0),
#  (160, 1370, 2.0),
#  (68, 46976, 4.0),
#  (50, 1380, 2.5),
#  (380, 55282, 2.0),
#  (249, 86911, 3.5),
#  (566, 434, 2.0),
#  (600, 3524, 4.0),
#  (608, 8528, 3.5),
#  (391, 368, 4.0),
#  (309, 4327, 4.0),
#  (298, 7162, 2.5),
#  (307, 4477, 4.0),
#  (448, 2502, 3.0),
#  (58, 39, 5.0),
#  (43, 349, 3.0),
#  (357, 1197, 4.5),
#  (307, 4534, 2.0),
#  (288, 3608, 3.5),
#  (526, 55247, 4.5),
#  (474, 30810, 3.0),
#  (45, 541, 3.0),
#  (105, 2360, 4.0),
#  (292, 3639, 4.0),
#  (288, 6305, 3.5),
#  (477, 5388, 4.0),
#  (298, 47518, 2.0),
#  (57, 2088, 1.0),
#  (387, 1245, 4.0),
#  (448, 78467, 2.0),
#  (552, 3173, 1.5),
#  (132, 52281, 4.0),
#  (64, 8014, 5.0),
#  (201, 2262, 3.0),
#  (405, 5810, 4.0),
#  (18, 32587, 3.5),
#  (80, 52604, 4.5),
#  (610, 156371, 5.0),
#  (295, 1375, 0.5),
#  (226, 4980, 4.0),
#  (18, 7147, 4.5),
#  (477, 1253, 4.0),
#  (438, 43928, 0.5),
#  (381, 3526, 3.0),
#  (253, 48394, 5.0),
#  (474, 3111, 4.0),
#  (314, 163, 3.0),
#  (489, 1391, 2.5),
#  (234, 2137, 4.0),
#  (41, 3160, 4.0),
#  (354, 7458, 3.0),
#  (489, 784, 0.5),
#  (600, 2329, 4.0),
#  (606, 2712, 4.0),
#  ...]

# %%
algo.predict(353, 904)
# Out:
# Prediction(uid=353, iid=904, r_ui=None, est=4.239282394498953, details={'actual_k': 40, 'was_impossible': False})

# %%
algo.get_neighbors(353, 40)
# Out:
# [3,
#  46,
#  62,
#  75,
#  79,
#  87,
#  100,
#  115,
#  121,
#  125,
#  131,
#  139,
#  143,
#  163,
#  193,
#  208,
#  221,
#  227,
#  232,
#  236,
#  241,
#  243,
#  253,
#  261,
#  303,
#  307,
#  311,
#  330,
#  338,
#  376,
#  382,
#  387,
#  390,
#  395,
#  404,
#  406,
#  411,
#  417,
#  421,
#  427]

# %%
algo.predict(algo.trainset.to_inner_uid(292), algo.trainset.to_inner_iid(164909))
# Out:
# Prediction(uid=58, iid=3282, r_ui=None, est=3.5022871522784746, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'})

# %%
algo.get_neighbors(iid=algo.trainset.to_inner_uid(353), k=5)
# Out:
# [15, 43, 84, 87, 94]

# %%
pd.merge(df[df['userId']==353], df[df['userId']==algo.trainset.to_raw_uid(87)], on='movieId')
# Out:
#    userId_x  movieId  rating_x                                     title_x  \
# 0       353        1       5.0                            Toy Story (1995)
# 1       353        6       4.0                                 Heat (1995)
# 2       353      112       5.0  Rumble in the Bronx (Hont faan kui) (1995)
#
#    userId_y  rating_y                                     title_y
# 0        44       3.0                            Toy Story (1995)
# 1        44       3.0                                 Heat (1995)
# 2        44       5.0  Rumble in the Bronx (Hont faan kui) (1995)

# %%
def get_votes_for_film_user(uid, iid):
    neighbors = algo.get_neighbors(iid=algo.trainset.to_inner_uid(uid), k=40)
    for n in neighbors:
        res = df_ratings[(df_ratings['userId'] == n) & (df_ratings['movieId'] == iid)]
        print (n, res['rating'].tolist()[0] if len(res['rating'].tolist()) > 0 else "None")

# %%
get_votes_for_film_user(353, 1)
# Out:
# 15 2.5
# 43 5.0
# 84 None
# 87 None
# 94 None
# 96 5.0
# 100 None
# 101 None
# 107 4.0
# 122 None
# 139 None
# 141 4.0
# 159 4.5
# 208 None
# 219 3.5
# 221 None
# 231 None
# 233 3.0
# 239 4.0
# 241 None
# 243 None
# 251 None
# 273 5.0
# 283 3.0
# 296 None
# 307 4.0
# 311 None
# 313 None
# 329 None
# 334 3.5
# 339 4.0
# 340 None
# 343 None
# 348 None
# 361 None
# 364 5.0
# 369 None
# 379 None
# 382 4.5
# 394 None

# %%
algo.predict(353, 1)
# Out:
# Prediction(uid=353, iid=1, r_ui=None, est=4.149814663807331, details={'actual_k': 40, 'was_impossible': False})

# %% [markdown]
# ## Item-based рекомендация

# %%
algo = KNNBasic(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})

# %%
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.6963
# 0.6962531062387705

# %%
from surprise import KNNWithMeans

# %%
algo = KNNWithMeans(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})

# %%
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
predictions = algo.test(testset)

# %%
accuracy.mae(predictions)
# Out:
# MAE:  0.6704
# 0.6704108257652016

# %%
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# 20           1      356     4.0   964980962
# 21           1      362     5.0   964982588
# 22           1      367     4.0   964981710
# 23           1      423     3.0   964982363
# 24           1      441     4.0   964980868
# 25           1      457     5.0   964981909
# 26           1      480     4.0   964982346
# 27           1      500     3.0   964981208
# 28           1      527     5.0   964984002
# 29           1      543     4.0   964981179
# ...        ...      ...     ...         ...
# 100806     610   150401     3.0  1479543210
# 100807     610   152077     4.0  1493845817
# 100808     610   152081     4.0  1493846503
# 100809     610   152372     3.5  1493848841
# 100810     610   155064     3.5  1493848456
# 100811     610   156371     5.0  1479542831
# 100812     610   156726     4.5  1493848444
# 100813     610   157296     4.0  1493846563
# 100814     610   158238     5.0  1479545219
# 100815     610   158721     3.5  1479542491
# 100816     610   158872     3.5  1493848024
# 100817     610   158956     3.0  1493848947
# 100818     610   159093     3.0  1493847704
# 100819     610   160080     3.0  1493848031
# 100820     610   160341     2.5  1479545749
# 100821     610   160527     4.5  1479544998
# 100822     610   160571     3.0  1493848537
# 100823     610   160836     3.0  1493844794
# 100824     610   161582     4.0  1493847759
# 100825     610   161634     4.0  1493848362
# 100826     610   162350     3.5  1493849971
# 100827     610   163937     3.5  1493848789
# 100828     610   163981     3.5  1493850155
# 100829     610   164179     5.0  1493845631
# 100830     610   166528     4.0  1493879365
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
similar_films = algo.get_neighbors(algo.trainset.to_inner_iid(1), k=10)

# %%
similar_films = [algo.trainset.to_raw_iid(i) for i in similar_films]

# %%
similar_films
# Out:
# [588, 3114, 6377, 8961, 1097, 2716, 2797, 2355, 1198, 3471]

# %%
df_movies[df_movies['movieId'].isin(similar_films)]
# Out:
#       movieId                                              title  \
# 506       588                                     Aladdin (1992)
# 836      1097                  E.T. the Extra-Terrestrial (1982)
# 900      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 1757     2355                               Bug's Life, A (1998)
# 2038     2716         Ghostbusters (a.k.a. Ghost Busters) (1984)
# 2103     2797                                         Big (1988)
# 2355     3114                                 Toy Story 2 (1999)
# 2596     3471          Close Encounters of the Third Kind (1977)
# 4360     6377                                Finding Nemo (2003)
# 5374     8961                            Incredibles, The (2004)
#
#                                            genres
# 506   Adventure|Animation|Children|Comedy|Musical
# 836                         Children|Drama|Sci-Fi
# 900                              Action|Adventure
# 1757          Adventure|Animation|Children|Comedy
# 2038                         Action|Comedy|Sci-Fi
# 2103                 Comedy|Drama|Fantasy|Romance
# 2355  Adventure|Animation|Children|Comedy|Fantasy
# 2596                       Adventure|Drama|Sci-Fi
# 4360          Adventure|Animation|Children|Comedy
# 5374   Action|Adventure|Animation|Children|Comedy

# %%
from surprise.model_selection import KFold

# %%
kfold = KFold(5)

# %%
scores = []
for trainset, testset in tqdm_notebook(kfold.split(dataset)):
    algo = KNNWithMeans(k=40, sim_options={'name': 'pearson_baseline', 'user_based': False})
    algo.fit(trainset)
    predictions = algo.test(testset)
    scores.append(accuracy.mae(predictions))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6679
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6729
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6659
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6771
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# MAE:  0.6684

# %%
scores
# Out:
# [0.667898127047499,
#  0.672901924296151,
#  0.6658599117298951,
#  0.6770688689744095,
#  0.6684150491909416]
